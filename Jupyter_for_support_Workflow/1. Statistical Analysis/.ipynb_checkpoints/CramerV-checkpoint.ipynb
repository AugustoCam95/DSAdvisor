# %%
import pandas as pd
data = pd.read_csv("../../all_csvs/artificial.csv")
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.455     0.365   0.095        0.5140          0.2245
# 1    M   0.350     0.265   0.090        0.2255          0.0995
# 2    F   0.530     0.420   0.135        0.6770          0.2565
# 3    M   0.440     0.365   0.125        0.5160          0.2155
# 4  NaN   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings  generate column 1  generate column 2  \
# 0          0.1010         0.150     15              -0.96               0.91
# 1          0.0485         0.070      7               0.39              -0.24
# 2          0.1415         0.210      9               0.38              -0.72
# 3          0.1140         0.155     10               0.65               0.21
# 4          0.0395         0.055      7               1.07               2.12
#
#    generate column 3  generate column 4 categorical2 categorical3
# 0              -0.36              -0.03            p            A
# 1              -1.21              -0.60            e            W
# 2              -1.75              -0.31            e            H
# 3               0.02               1.69            p            W
# 4               0.25              -1.61          NaN          NaN

# %%
# for col in data.columns:
#     if data[col].dtypes == 'float64' or data[col].dtypes == 'int64':
#         data = data.drop( columns = [col])

# %%
data
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       M   0.455     0.365   0.095        0.5140          0.2245
# 1       M   0.350     0.265   0.090        0.2255          0.0995
# 2       F   0.530     0.420   0.135        0.6770          0.2565
# 3       M   0.440     0.365   0.125        0.5160          0.2155
# 4     NaN   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    F   0.565     0.450   0.165        0.8870          0.3700
# 4173    M   0.590     0.440   0.135        0.9660          0.4390
# 4174    M   0.600     0.475   0.205        1.1760          0.5255
# 4175    F   0.625     0.485   0.150        1.0945          0.5310
# 4176    M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings  generate column 1  \
# 0             0.1010        0.1500     15              -0.96
# 1             0.0485        0.0700      7               0.39
# 2             0.1415        0.2100      9               0.38
# 3             0.1140        0.1550     10               0.65
# 4             0.0395        0.0550      7               1.07
# ...              ...           ...    ...                ...
# 4172          0.2390        0.2490     11              -1.17
# 4173          0.2145        0.2605     10              -0.90
# 4174          0.2875        0.3080      9               0.02
# 4175          0.2610        0.2960     10              -1.72
# 4176          0.3765        0.4950     12              -0.91
#
#       generate column 2  generate column 3  generate column 4 categorical2  \
# 0                  0.91              -0.36              -0.03            p
# 1                 -0.24              -1.21              -0.60            e
# 2                 -0.72              -1.75              -0.31            e
# 3                  0.21               0.02               1.69            p
# 4                  2.12               0.25              -1.61          NaN
# ...                 ...                ...                ...          ...
# 4172               0.78               1.57              -0.49            p
# 4173              -0.16               0.21               0.96            p
# 4174              -0.83               0.32               0.19            p
# 4175               1.29               0.32              -0.53            p
# 4176              -0.65               0.81              -1.05            e
#
#      categorical3
# 0               A
# 1               W
# 2               H
# 3               W
# 4             NaN
# ...           ...
# 4172            W
# 4173            H
# 4174            W
# 4175            B
# 4176            B
#
# [4177 rows x 15 columns]

# %%
for col in data.columns:
    if data[col].dtype == "object":
        for i in data[col]:
            data[col] = str(data[col])

# %%
from sklearn import preprocessing

label = preprocessing.LabelEncoder()
data_encoded = pd.DataFrame() 

for i in data.columns :
    data_encoded[i]=label.fit_transform(data[i])

# %%
data_encoded.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    0      66        56      18           715             417
# 1    0      45        36      17           285             178
# 2    0      81        67      26           962             480
# 3    0      63        56      24           718             400
# 4    0      41        34      15           253             159
#
#    Viscera weight  Shell weight  Rings  generate column 1  generate column 2  \
# 0             199           263     14                156                340
# 1              94           113      6                291                225
# 2             280           374      8                290                177
# 3             225           273      9                317                270
# 4              76            87      6                359                459
#
#    generate column 3  generate column 4  categorical2  categorical3
# 0                223                249             0             0
# 1                138                192             0             0
# 2                 85                221             0             0
# 3                261                420             0             0
# 4                284                 91             0             0

# %%
from scipy.stats import chi2_contingency
import numpy as np




def cramers_V(var1,var2) :
    crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
    stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
    obs = np.sum(crosstab) # Number of observations
    mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
    return (stat/(obs*mini))

# %%
rows= []

for var1 in data_encoded:
    col = []
    for var2 in data_encoded :
        cramers =cramers_V(data_encoded[var1], data_encoded[var2]) # Cramer's V test
        col.append(round(cramers,2)) # Keeping of the rounded value of the Cramer's V  
    rows.append(col)
  
cramers_results = np.array(rows)
df = pd.DataFrame(cramers_results, columns = data_encoded.columns, index =data_encoded.columns)



df
# Out:
# <ipython-input-33-19e91dc8458e>:12: RuntimeWarning: invalid value encountered in true_divide
#   return (stat/(obs*mini))
#                    Sex  Length  Diameter  Height  Whole weight  \
# Sex                NaN     NaN       NaN     NaN           NaN
# Length             NaN    1.00      0.21    0.17          0.68
# Diameter           NaN    0.21      1.00    0.16          0.70
# Height             NaN    0.17      0.16    1.00          0.68
# Whole weight       NaN    0.68      0.70    0.68          1.00
# Shucked weight     NaN    0.47      0.50    0.48          0.62
# Viscera weight     NaN    0.33      0.34    0.35          0.64
# Shell weight       NaN    0.34      0.39    0.37          0.63
# Rings              NaN    0.16      0.14    0.11          0.65
# generate column 1  NaN    0.12      0.12    0.12          0.58
# generate column 2  NaN    0.12      0.12    0.13          0.59
# generate column 3  NaN    0.13      0.13    0.13          0.59
# generate column 4  NaN    0.12      0.13    0.13          0.58
# categorical2       NaN     NaN       NaN     NaN           NaN
# categorical3       NaN     NaN       NaN     NaN           NaN
#
#                    Shucked weight  Viscera weight  Shell weight  Rings  \
# Sex                           NaN             NaN           NaN    NaN
# Length                       0.47            0.33          0.34   0.16
# Diameter                     0.50            0.34          0.39   0.14
# Height                       0.48            0.35          0.37   0.11
# Whole weight                 0.62            0.64          0.63   0.65
# Shucked weight               1.00            0.44          0.42   0.46
# Viscera weight               0.44            1.00          0.29   0.31
# Shell weight                 0.42            0.29          1.00   0.29
# Rings                        0.46            0.31          0.29   1.00
# generate column 1            0.36            0.21          0.23   0.12
# generate column 2            0.36            0.21          0.22   0.12
# generate column 3            0.36            0.21          0.22   0.14
# generate column 4            0.36            0.21          0.23   0.12
# categorical2                  NaN             NaN           NaN    NaN
# categorical3                  NaN             NaN           NaN    NaN
#
#                    generate column 1  generate column 2  generate column 3  \
# Sex                              NaN                NaN                NaN
# Length                          0.12               0.12               0.13
# Diameter                        0.12               0.12               0.13
# Height                          0.12               0.13               0.13
# Whole weight                    0.58               0.59               0.59
# Shucked weight                  0.36               0.36               0.36
# Viscera weight                  0.21               0.21               0.21
# Shell weight                    0.23               0.22               0.22
# Rings                           0.12               0.12               0.14
# generate column 1               1.00               0.12               0.13
# generate column 2               0.12               1.00               0.12
# generate column 3               0.13               0.12               1.00
# generate column 4               0.13               0.12               0.12
# categorical2                     NaN                NaN                NaN
# categorical3                     NaN                NaN                NaN
#
#                    generate column 4  categorical2  categorical3
# Sex                              NaN           NaN           NaN
# Length                          0.12           NaN           NaN
# Diameter                        0.13           NaN           NaN
# Height                          0.13           NaN           NaN
# Whole weight                    0.58           NaN           NaN
# Shucked weight                  0.36           NaN           NaN
# Viscera weight                  0.21           NaN           NaN
# Shell weight                    0.23           NaN           NaN
# Rings                           0.12           NaN           NaN
# generate column 1               0.13           NaN           NaN
# generate column 2               0.12           NaN           NaN
# generate column 3               0.12           NaN           NaN
# generate column 4               1.00           NaN           NaN
# categorical2                     NaN           NaN           NaN
# categorical3                     NaN           NaN           NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# mask = np.zeros_like(df, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True




# with sns.axes_style("white"):
#     ax = sns.heatmap(df,  annot= True)

# plt.show()

fig, ax = plt.subplots(figsize=(15,10))
map3 = sns.heatmap(df, annot= True,  ax = ax, linewidth=0.5, cmap='YlGnBu')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (15.5, -0.5)
